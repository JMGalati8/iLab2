# %%
import requests
import pandas as pd
import json
import time
from sqlalchemy import engine, create_engine

# %%
temp = requests.get('https://api.crossref.org/works?query.bibliographic=Quantum&query.author=Ford&filter=has-references:true&mailto=J_M_Galati@hotmail.com&rows=1000&cursor=*').json()

# %%
for paper in temp['message']['items']:
    [print(paper) for s in paper['title'] if 'Emission from Hexagonal Boron'.upper() in s.upper()]
# Out:
# {'indexed': {'date-parts': [[2019, 2, 16]], 'date-time': '2019-02-16T05:02:28Z', 'timestamp': 1550293348540}, 'publisher-location': 'Washington, D.C.', 'reference-count': 13, 'publisher': 'OSA', 'isbn-type': [{'value': '9781943580118', 'type': 'print'}], 'content-domain': {'domain': [], 'crossmark-restriction': False}, 'published-print': {'date-parts': [[2016]]}, 'DOI': '10.1364/cleo_qels.2016.ftu4d.1', 'type': 'proceedings-article', 'created': {'date-parts': [[2016, 5, 31]], 'date-time': '2016-05-31T21:07:05Z', 'timestamp': 1464728825000}, 'source': 'Crossref', 'is-referenced-by-count': 0, 'title': ['Quantum Emission from Hexagonal Boron Nitride Monolayers'], 'prefix': '10.1364', 'author': [{'given': 'Toan Trong', 'family': 'Tran', 'sequence': 'first', 'affiliation': []}, {'given': 'Kerem', 'family': 'Bray', 'sequence': 'additional', 'affiliation': []}, {'given': 'Michael J.', 'family': 'Ford', 'sequence': 'additional', 'affiliation': []}, {'given': 'Milos', 'family': 'Toth', 'seque
# ...
